# %% [markdown]
# <a href="https://colab.research.google.com/github/AliceGomessilva/INTMI_2025/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = (int(input("digite um número")))
if num1 > 0:
  print(('Positivo'))
elif num1 == 0:
  print("zero")
else:
  print("Negativo")
# Out:
# digite um número15
# Positivo

# %%
#1
num1 = (int(input("Digite um número")));
if num1 > 10:
    print("Maior que 10")
elif num1 == 10:
    print("Numero 10")
else:
      print("Menor que 10")
# Out:
# Digite um número8
# Menor que 10

# %%
#2
num = (int(input("Digie um Número")))
if num %2 == 0:
  print("Par")
else:
    print("Ímpar")

# %%
#3
Name = (str(input("Digite seu nome")))
if "a" in Name:
  print("Contém a letra a")
else:
  print("Não há letra a no nome")
# Out:
# Digite seu nomealica
# Contém a letra A

# %%
#4
num = (int(input("Digite um número")))
if num %5 == 0:
  print ("É divisível por 5")
else:
  print("Não é divisível por 5")
# Out:
# Digite um número10
# É divisível por 5

# %%
#5
temp = (int(input("Me dê a temperatura atual")))
if temp >= 30:
  print("Quente")
else:
  print("Frio")
# Out:
# Me dê a temperatura atual9
# Frio

# %%
#6
num = (str(input("Digite 'S' para continuar e 'N' para sair")))
if "S" in num:
  print("Continuar")
elif "N" in num:
  print("Sair")
else:
  print("Invalido")
# Out:
# Digite 'S' para continuar e 'N' para sairS]
# Continuar

# %%
#7
num = (int(input("Digite um numero")));
if num >= 1:
  print("Positivo")
elif num == 0:
  print("Zero")
else:
  print("Negativo")
# Out:
# Digite um numero9
# Positivo

# %%
#8
num = (int(input("digite um numero de um a 7")));
if num == 1:
  print("domingo")
elif num == 2:
  print("segunda")
elif num == 3:
  print("Terça")
elif num == 4:
  print("Quarta")
elif num == 5:
  print("Quinta")
elif num == 6:
  print("Sexta")
elif num == 7:
  print("Sabado")
# Out:
# digite um numero de um a 75
# Quinta

# %%
#9
ano = (int(input("Digite um ano")))
if ano %4 == 0:
  print("Bissexto")
else:
  print("Não é bissexto")
# Out:
# Digite um ano1987
# Não é bissexto

# %%
#10
hor = (int(input("Digite a quantidade de horas trabalhadas")))
val = (int(input("Digite o valor por hora")))
if hor <= 40:
  print(hor*val)
else:
  print(hor*val*1.5)
# Out:
# Digite a quantidade de horas trabalhadas30
# Digite o valor por hora20
# 600
